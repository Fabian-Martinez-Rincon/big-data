# %% [markdown]
# <div aling='center'>
#
# # Entrega 1
#
# </div>
#
# ### Enunciado
# Ha sido contratado para el análisis de uso de un videojuego online donde millones de jugadores se conectan a diario para combatir con otros jugadores. En un combate, un jugador “retador” elije un oponente (jugador “retado”) y como resultado del combate el retador obtiene un puntaje y el tiempo en segundos que duró el combate. Por cada combate, los servidores del videojuego almacena la siguiente información:
#
# - ID_Jugador_Retador
# - ID_Jugador_Retado
# - Puntaje obtenido (por el retador)
# - Tiempo del combate en segundos
#
# Todos los jugadores pueden participar cuántas veces deseen y por cada combate obtienen un puntaje y también se registra el tiempo que duró el combate. Un jugador puede combatir todas las veces que quiera.
#
# Un fragmento del dataset de este jugador podría ser:
#
# | ID_Jug_Retador | ID_Jugador_Retado | Puntos | Tiempo |
# |---------------|-------------------|--------|--------|
# | 231            | 492                | 1054   | 621    |
# | 231            | 492                | 2068   | 504    |
# | 231            | 98                 | 789    | 302    |
# | 492            | 501                | 5462   | 955    |

# %% [markdown]
# Semanalmente los administradores del juego quieren obtener algunas estadísticas para regalarle premios a los mejores jugadores y armar el ranking semanal. Al finalizar la semana se desea saber:
# ### 1) El jugador más “retador” y el jugador más “retado”.
#
# ---
#
# **Explicación**
#
# En este ejemplo se utiliza el framework `MRE` para ejecutar un **Job MapReduce** que procesa los combates de jugadores.
#
# - En la **fase Map**, se identifican los jugadores que aparecen como *retadores* y *retados* en cada línea de entrada.
# - En la **fase Reduce**, se cuentan cuántas veces aparece cada jugador y se determina cuál fue el más frecuente dentro de cada grupo.
#
# De esta forma, el job permite identificar el jugador con mayor participación en los combates, ya sea como retador o como retado.

# %%
import sys
sys.path.append("..") 
from MRE import Job

inputDir = "../Datasets/TP1/input/"
outputDir = "../Datasets/TP1/out_punto1/"

def fmap(key, value, context):
    cols = value.strip().split()
    id_retador = key
    id_retado  = cols[0]
    context.write("RETADOR", id_retador)
    context.write("RETADO",  id_retado)

def fred(key, values, context):
    conteos = dict()
    for jugador in values:
        conteos[jugador] = conteos.get(jugador, 0) + 1
    jugador_max = max(conteos, key=conteos.get)
    context.write(key, (jugador_max, conteos[jugador_max]))

job = Job(inputDir, outputDir, fmap, fred)
success = job.waitForCompletion()
# Out:
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] RETADOR -> 15
# [Map] RETADO -> 89
# [Map] RETADOR -> 65
# [Map] RETADO -> 51
# [Map] RETADOR -> 82
# [Map] RETADO -> 93
# [Map] RETADOR -> 63
# [Map] RETADO -> 33
# [Map] RETADOR -> 103
# [Map] RETADO -> 33
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: RETADO -> ['89', '51', '93', '33', '33', '17', '62', '70', '28', '66', '...']
# [Reduce] Clave recibida: RETADOR -> ['15', '65', '82', '63', '103', '76', '3', '66', '3', '29', '...']
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# RETADO	('43', 15)
# RETADOR	('1', 18)

# %% [markdown]
# ---
#
# ### 2) El jugador que más puntos obtuvo en promedio
#
# $$
# PP_i = \frac{puntaje\_total\_de\_todos\_los\_combates_i + 1}{cantidad\_de\_combates\_como\_retador_i + 1}
# $$
#
# *(el +1 en el numerador y en el denominador es para evitar divisiones por cero en el caso que un jugador no haya “retado” a nadie, en cuyo caso tendrá el puntaje mínimo de 1).*
#
# ---
#
# **Explicación**
#
# En este job se busca calcular el **puntaje promedio** obtenido por cada jugador que actúa como *retador*.
#
# - En la **fase Map**, se emiten pares con el ID del retador y su puntaje junto a un contador de combates.
# - En la **fase Reduce**, se acumulan los puntajes y combates para cada jugador y se aplica la fórmula:
#
# \[
# \text{Promedio} = \frac{\text{total\_puntos} + 1}{\text{total\_combates} + 1}
# \]
#
# El término `+1` se utiliza para evitar divisiones por cero y suavizar el cálculo cuando hay pocos combates.

# %%
import sys
sys.path.append("..") 
from MRE import Job

inputDir = "../Datasets/TP1/input/"
outputDir = "../Datasets/TP1/out_punto2/"

def fmap2(key, value, context):
    cols = value.strip().split()
    id_retador = key
    puntaje = int(cols[1]) if len(cols) == 3 else int(cols[2])
    context.write(id_retador, (puntaje, 1))

def fred2(key, values, context):
    total_puntos, total_combates = 0, 0
    for puntos, combates in values:
        total_puntos += puntos
        total_combates += combates
    # fórmula con +1
    promedio = (total_puntos + 1) / (total_combates + 1)
    context.write("PROMEDIO", (key, promedio))

job = Job(inputDir, outputDir, fmap2, fred2)
success = job.waitForCompletion()
# Out:
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> (707, 1)
# [Map] 65 -> (2411, 1)
# [Map] 82 -> (3814, 1)
# [Map] 63 -> (1033, 1)
# [Map] 103 -> (4988, 1)
# [Map] 76 -> (1692, 1)
# [Map] 3 -> (1202, 1)
# [Map] 66 -> (4625, 1)
# [Map] 3 -> (2396, 1)
# [Map] 29 -> (1867, 1)
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [(1896, 1), (2094, 1), (4432, 1), (4631, 1), (2548, 1), (1986, 1), (3657, 1), (2040, 1), (3308, 1), (827, 1), '...']
# [Reduce] Clave recibida: 10 -> [(323, 1), (2905, 1), (749, 1)]
# [Reduce] Clave recibida: 100 -> [(4529, 1)]
# [Reduce] Clave recibida: 102 -> [(1220, 1), (2295, 1), (1641, 1), (2828, 1)]
# [Reduce] Clave recibida: 103 -> [(4988, 1)]
# [Reduce] Clave recibida: 104 -> [(4783, 1)]
# [Reduce] Clave recibida: 11 -> [(1411, 1)]
# [Reduce] Clave recibida: 113 -> [(3049, 1)]
# [Reduce] Clave recibida: 116 -> [(3786, 1)]
# [Reduce] Clave recibida: 12 -> [(3736, 1), (3886, 1), (1037, 1)]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# PROMEDIO	('1', 1818.2631578947369)
# PROMEDIO	('10', 994.5)
# PROMEDIO	('100', 2265.0)
# PROMEDIO	('102', 1597.0)
# PROMEDIO	('103', 2494.5)
# PROMEDIO	('104', 2392.0)
# PROMEDIO	('11', 706.0)
# PROMEDIO	('113', 1525.0)
# PROMEDIO	('116', 1893.5)
# PROMEDIO	('12', 2165.0)
# ... [más resultados omitidos]

# %% [markdown]
# ### Promedio que no es big data

# %%
import os
mejor = ("", -1)
with open(os.path.join(outputDir, "output.txt")) as f:
    for line in f:
        _, jugador, promedio = line.strip().split("\t")
        promedio = float(promedio)
        if promedio > mejor[1]:
            mejor = (jugador, promedio)

print("\nConsulta 2:")
print(f"El jugador con más puntos en promedio: {mejor[0]} con {mejor[1]:.2f}")
# Out:
# Consulta 2:
# El jugador con más puntos en promedio: 53 con 3504.43

# %% [markdown]
# ---
#
# ### 3) Todos los jugadores que “retaron” a más de **H** oponentes **distintos**
#
# *(H es un parámetro de la consulta).*
#
# ---
#
# **Explicación**
#
# Este job identifica a los jugadores que han retado a más de **H** oponentes diferentes.
#
# - En la **fase Map**, se emiten pares con el ID del retador y del oponente retado.
# - En la **fase Reduce**, se agrupan todos los oponentes retados por cada jugador y se cuentan los **distintos**.
# - Si la cantidad supera el umbral `H`, el jugador se considera parte del resultado.
#
# De esta forma se obtiene la lista de jugadores con mayor diversidad de oponentes en sus combates.

# %%
import sys
sys.path.append("..") 
from MRE import Job

inputDir = "../Datasets/TP1/input/"
outputDir = "../Datasets/TP1/out_punto3/"

# Parámetro H
H = 12

def fmap3(key, value, context):
    cols = value.strip().split()
    id_retador = key
    id_retado  = cols[0]
    context.write(id_retador, id_retado)

def fred3(key, values, context):
    oponentes = set()
    for v in values:
        oponentes.add(v)
    cantidad = len(oponentes)
    context.write("DISTINTOS", (key, cantidad))

job = Job(inputDir, outputDir, fmap3, fred3)
success = job.waitForCompletion()
# Out:
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 89
# [Map] 65 -> 51
# [Map] 82 -> 93
# [Map] 63 -> 33
# [Map] 103 -> 33
# [Map] 76 -> 17
# [Map] 3 -> 62
# [Map] 66 -> 70
# [Map] 3 -> 28
# [Map] 29 -> 66
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> ['73', '48', '49', '2', '37', '23', '48', '64', '47', '15', '...']
# [Reduce] Clave recibida: 10 -> ['64', '8', '60']
# [Reduce] Clave recibida: 100 -> ['67']
# [Reduce] Clave recibida: 102 -> ['52', '53', '23', '81']
# [Reduce] Clave recibida: 103 -> ['33']
# [Reduce] Clave recibida: 104 -> ['61']
# [Reduce] Clave recibida: 11 -> ['49']
# [Reduce] Clave recibida: 113 -> ['27']
# [Reduce] Clave recibida: 116 -> ['42']
# [Reduce] Clave recibida: 12 -> ['48', '50', '25']
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# DISTINTOS	('1', 15)
# DISTINTOS	('10', 3)
# DISTINTOS	('100', 1)
# DISTINTOS	('102', 4)
# DISTINTOS	('103', 1)
# DISTINTOS	('104', 1)
# DISTINTOS	('11', 1)
# DISTINTOS	('113', 1)
# DISTINTOS	('116', 1)
# DISTINTOS	('12', 3)
# ... [más resultados omitidos]

# %% [markdown]
# ### Procedimiento que no es big data

# %%
import os
jugadores = []
with open(os.path.join(outputDir, "output.txt")) as f:
    for line in f:
        _, jugador, cantidad = line.strip().split("\t")
        cantidad = int(cantidad)
        if cantidad >= H:
            jugadores.append(jugador)

print("\nConsulta 3:")
print(f"Con H = {H}")
print("Jugadores que retaron a más de H oponentes distintos:", jugadores)
# Out:
# Consulta 3:
# Con H = 12
# Jugadores que retaron a más de H oponentes distintos: ['1', '48', '55', '65']

# %% [markdown]
# ---
#
# ### 4) El top 10 de los jugadores con mejor puntaje heroico
#
# El puntaje **PH** de un jugador *i* se calcula como:
#
# $$
# PH_i = \alpha \left( \sum_{j=1}^{n} PH_j \cdot \frac{PP_i}{PP_j} \right) + (1 - \alpha)
# $$
#
# donde:
#
# - *n* es la cantidad de jugadores “retados” por el jugador *i*.
# - *PH_j* es el puntaje **P** del *j*-ésimo jugador retado por *i*.
# - *PP_i* es el puntaje promedio del jugador *i*.
# - *PP_j* es el puntaje promedio del *j*-ésimo jugador retado por *i*.
# - *α* es un parámetro del algoritmo.
#
# <details><summary>Nota sobre el cálculo del puntaje heroico (PH)</summary>
#
# Como para calcular el puntaje **PH** de un jugador *i* previamente hay que calcular el puntaje de los jugadores a quiénes retó (y a su vez éstos pueden haber retado al jugador *i*), el cálculo se realiza de manera **iterativa**.
#
# Se comienza asignando el mismo puntaje heroico con un valor arbitrario a todos los jugadores (**tiempo 0**).
# Con esos puntajes arbitrarios se calcula el puntaje usando la fórmula detallada para obtener los nuevos puntajes (**tiempo 1**),
# con éstos se calculan los nuevos puntajes (**tiempo 2**) y así se continúa hasta alcanzar una **convergencia en los valores**.
#
# > 📌 Al final de este documento hay un ejemplo que explica este cálculo iterativo.
#
# </details>
#
# <details><summary>Implementación</summary>
#
# Implemente la cantidad de **jobs** necesarios para resolver las cuatro consultas.
# Utilice el archivo `jugadores.txt` para realizar las pruebas *(Se ofrecen los resultados de cada consulta)*.
#
# </details>
#
# <details><summary>⚠️ Aclaración</summary>
#
# Suponga que la cantidad de jugadores y de combates es **“Big Data”**.
#
# En cada **job** planteado en la solución, piense si una función **combiner** contribuye o no para la optimización del job.
# En caso de contribuir, implemente dicha función.
#
# </details>

# %% [markdown]
# # Implementación MapReduce: Cálculo del Puntaje Heroico
#
# En este trabajo se aplica el paradigma **MapReduce** para analizar información de combates entre jugadores de un videojuego online.
# Se implementan tres *jobs* secuenciales:
#
# 1. **Job 1 – Filtrado de datos**
#    Limpia las líneas de entrada y deja solo aquellas con formato válido.
#
# 2. **Job 2 – Cálculo del Promedio de Puntaje (PP)**
#    Calcula el puntaje promedio obtenido por cada jugador retador.
#
# 3. **Job 3 – Cálculo del Puntaje Heroico (PH)**
#    Itera aplicando una fórmula de propagación de prestigio entre jugadores hasta alcanzar convergencia.
#
# Finalmente, se muestra el **Top 10 de jugadores más heroicos**.

# %%
import sys, os, re
sys.path.append("..")
from MRE import Job

BASE_DIR = os.path.join(os.getcwd(), "Datasets", "TP1")

input_path  = os.path.join(BASE_DIR, "input")
job1_out    = os.path.join(BASE_DIR, "out_filtrar")
job2_out    = os.path.join(BASE_DIR, "out_pp")
job3_out    = os.path.join(BASE_DIR, "out_ph")

# Crear las carpetas de salida si no existen
for path in [input_path, job1_out, job2_out, job3_out]:
    os.makedirs(path, exist_ok=True)

print("Estructura de carpetas lista")
# Out:
# Estructura de carpetas lista

# %% [markdown]
# ## Job 1 – Filtrado de datos
#
# El objetivo de este primer *job* es leer los combates desde el archivo `jugadores.txt`,
# verificar que cada línea tenga los tres campos esperados (`retador`, `puntos`, `tiempo`)
# y emitir solo los registros válidos para procesar en las etapas siguientes.

# %%
def fmap_filtrar(key, value, context):
    parts = value.strip().split()
    retador, puntos, tiempo = parts
    puntos, tiempo = float(puntos), float(tiempo)
    context.write(retador, (puntos, tiempo))

def fred_filtrar(key, values, context):
    for v in values:
        context.write(key, v)

print("Funciones Map y Reduce del Job 1 definidas correctamente")
# Out:
# Funciones Map y Reduce del Job 1 definidas correctamente

# %% [markdown]
# ## Job 2 – Cálculo del promedio de puntaje (PP)
#
# Cada jugador puede participar en múltiples combates.
# En este *job* se calcula su puntaje promedio acumulando las puntuaciones individuales.

# %%
def fmap_pp(key, value, context):
    if isinstance(value, tuple):
        puntos, tiempo = value
    else:
        puntos, tiempo = map(float, value.strip().split())
    context.write(key, ("P", puntos))

def fred_pp(key, values, context):
    total_p, n = 0.0, 0
    for tag, val in values:
        if tag == "P":
            total_p += val
            n += 1
    if n > 0:
        promedio = total_p / n
        context.write(key, promedio)

print("Funciones Map y Reduce del Job 2 definidas correctamente")
# Out:
# Funciones Map y Reduce del Job 2 definidas correctamente

# %% [markdown]
# ## Job 3 – Cálculo del Puntaje Heroico (PH)
#
# El puntaje heroico se calcula iterativamente aplicando una fórmula de propagación basada en el *prestigio* de los oponentes.
#
# La idea es que un jugador tiene mayor **PH** si derrota a oponentes con alto PH y con mejor PP (puntaje promedio).
#
# Se utiliza la siguiente fórmula:
#
# $$
# PH_{nuevo}(i) = \alpha \sum_j \left( PH_{previo}(j) \times \frac{PP(i)}{PP(j)} \right) + (1 - \alpha)
# $$

# %%
def fmap_ph(retador, value, context):
    parts = re.split(r'[\t\s]+', value.strip())
    retado, puntos, tiempo = map(float, parts)
    retador = int(retador)
    retado = int(retado)

    pp = context["pp"]
    ph_prev = context["ph_prev"]
    alpha = context["alpha"]

    if retador not in pp or retado not in pp or retado not in ph_prev:
        return
    if pp[retado] == 0:
        return

    contrib = ph_prev[retado] * (pp[retador] / pp[retado])
    context.write(retador, contrib)

def fred_ph(jugador, values, context):
    vals = list(values)
    if not vals:
        print(f"[REDUCE][JOB3] Jugador {jugador} sin contribuciones.")
        return

    total = sum(vals)
    alpha = context["alpha"]
    nuevo_ph = alpha * total + (1 - alpha)

    context.write(jugador, nuevo_ph)

print("Funciones Map y Reduce del Job 3 definidas correctamente")
# Out:
# Funciones Map y Reduce del Job 3 definidas correctamente

# %% [markdown]
# ## Funciones auxiliares
#
# Estas funciones permiten leer los resultados de cada job,
# procesar los archivos de salida y generar el Top 10 final.

# %%
def leer_resultados(path):
    res = {}
    try:
        archivos = [f for f in os.listdir(path) if f.startswith("part") or f.startswith("output")]
        if not archivos:
            print(f"[WARN] No se encontró ningún archivo en {path}")
            return res

        file_path = os.path.join(path, archivos[0])
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line or "\t" not in line:
                    continue
                k, v = line.split("\t", 1)
                try:
                    res[int(k)] = float(v.strip().replace("(", "").replace(")", "").replace(",", ""))
                except ValueError:
                    continue
    except FileNotFoundError:
        print(f"[WARN] Carpeta no encontrada: {path}")
    print(f"[DEBUG] Leídos {len(res)} resultados desde {path}")
    return res

def guardar_top10(top10, path):
    out_path = os.path.join(path, "top10.txt")
    with open(out_path, "w", encoding="utf-8") as f:
        for j, p in top10:
            f.write(f"{j}\t{p:.2f}\n")

# %% [markdown]
# ## 🚀 Ejecución del pipeline completo

# %%
print(f"\n[DEBUG] Archivos en {input_path}: {os.listdir(input_path)}")

# JOB 1
print("\n========== INICIANDO JOB 1: FILTRADO ==========")
job1 = Job(input_path, job1_out, fmap_filtrar, fred_filtrar)
job1.waitForCompletion()
print("[OK] Job 1 completado")

# JOB 2
print("\n========== INICIANDO JOB 2: PROMEDIO DE PUNTAJES ==========")
job2 = Job(job1_out, job2_out, fmap_pp, fred_pp)
job2.waitForCompletion()
pp = leer_resultados(job2_out)
print(f"[OK] Job 2 completado | Jugadores con PP calculado: {len(pp)}")

# JOB 3
print("\n========== INICIANDO JOB 3: PUNTAJE HEROICO ==========")
jugadores = set(pp.keys())
with open(os.path.join(input_path, "jugadores.txt"), "r", encoding="utf-8") as f:
    for linea in f:
        partes = linea.strip().split()
        if len(partes) == 4:
            jugadores.add(int(partes[1]))
ph = {j: 1.0 for j in jugadores}

alpha, error, max_iter = 0.202, 0.1, 20

for i in range(max_iter):
    print(f"\n---- Iteración {i+1} ----")
    job3 = Job(input_path, job3_out, fmap_ph, fred_ph)
    job3.setParams({"pp": pp, "ph_prev": ph, "alpha": alpha})
    job3.waitForCompletion()

    nuevo_ph = leer_resultados(job3_out)
    if not nuevo_ph:
        print("[WARN] No se obtuvieron nuevos PH")
        break

    dif = sum(abs(nuevo_ph[j] - ph.get(j, 0)) for j in nuevo_ph) / len(nuevo_ph)
    print(f"[INFO] Iter {i+1} | Diferencia promedio Δ={dif:.4f}")

    ph = nuevo_ph
    if dif < error:
        print(f"[INFO] ✅ Convergencia alcanzada en {i+1} iteraciones.")
        break

print("\n========== TOP 10 FINAL ==========")
top10 = sorted(ph.items(), key=lambda x: x[1], reverse=True)[:10]
for j, p in top10:
    print(f"(Jugador = {j}, PH = {p:.2f})")
guardar_top10(top10, job3_out)
print(f"[OK] Resultados guardados en: {job3_out}")
# Out:
# [DEBUG] Archivos en C:\Users\Fabian\Desktop\big-data\Datasets\TP1\input: ['jugadores.txt']
#
# ========== INICIANDO JOB 1: FILTRADO ==========
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 89 -> (707.0, 176.0)
# [Map] 51 -> (2411.0, 416.0)
# [Map] 93 -> (3814.0, 276.0)
# [Map] 33 -> (1033.0, 143.0)
# [Map] 33 -> (4988.0, 938.0)
# [Map] 17 -> (1692.0, 496.0)
# [Map] 62 -> (1202.0, 279.0)
# [Map] 70 -> (4625.0, 628.0)
# [Map] 28 -> (2396.0, 394.0)
# [Map] 66 -> (1867.0, 260.0)
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [(2568.0, 352.0), (2663.0, 919.0), (644.0, 684.0), (739.0, 215.0), (3591.0, 731.0), (290.0, 784.0), (4972.0, 343.0), (3353.0, 127.0), (1408.0, 188.0), (2539.0, 530.0), '...']
# [Reduce] Clave recibida: 10 -> [(827.0, 611.0), (3945.0, 67.0)]
# [Reduce] Clave recibida: 100 -> [(4516.0, 886.0)]
# [Reduce] Clave recibida: 101 -> [(3468.0, 379.0)]
# [Reduce] Clave recibida: 104 -> [(3739.0, 300.0), (3803.0, 901.0)]
# [Reduce] Clave recibida: 105 -> [(2170.0, 668.0)]
# [Reduce] Clave recibida: 106 -> [(2127.0, 581.0), (2650.0, 948.0)]
# [Reduce] Clave recibida: 11 -> [(1744.0, 75.0), (3529.0, 233.0)]
# [Reduce] Clave recibida: 112 -> [(4743.0, 541.0)]
# [Reduce] Clave recibida: 114 -> [(1413.0, 876.0)]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	(2568.0, 352.0)
# 1	(2663.0, 919.0)
# 1	(644.0, 684.0)
# 1	(739.0, 215.0)
# 1	(3591.0, 731.0)
# 1	(290.0, 784.0)
# 1	(4972.0, 343.0)
# 1	(3353.0, 127.0)
# 1	(1408.0, 188.0)
# 1	(2539.0, 530.0)
# ... [más resultados omitidos]
# [OK] Job 1 completado
#
# ========== INICIANDO JOB 2: PROMEDIO DE PUNTAJES ==========
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 1 -> ('P', 2568.0)
# [Map] 1 -> ('P', 4088.0)
# [Map] 105 -> ('P', 2170.0)
# [Map] 139 -> ('P', 875.0)
# [Map] 17 -> ('P', 243.0)
# [Map] 19 -> ('P', 4100.0)
# [Map] 21 -> ('P', 1886.0)
# [Map] 23 -> ('P', 1641.0)
# [Map] 25 -> ('P', 1262.0)
# [Map] 27 -> ('P', 4078.0)
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [('P', 2568.0), ('P', 4088.0), ('P', 2663.0), ('P', 3519.0), ('P', 644.0), ('P', 3898.0), ('P', 739.0), ('P', 2955.0), ('P', 3591.0), ('P', 290.0), '...']
# [Reduce] Clave recibida: 10 -> [('P', 827.0), ('P', 3945.0)]
# [Reduce] Clave recibida: 100 -> [('P', 4516.0)]
# [Reduce] Clave recibida: 101 -> [('P', 3468.0)]
# [Reduce] Clave recibida: 104 -> [('P', 3739.0), ('P', 3803.0)]
# [Reduce] Clave recibida: 105 -> [('P', 2170.0)]
# [Reduce] Clave recibida: 106 -> [('P', 2127.0), ('P', 2650.0)]
# [Reduce] Clave recibida: 11 -> [('P', 1744.0), ('P', 3529.0)]
# [Reduce] Clave recibida: 112 -> [('P', 4743.0)]
# [Reduce] Clave recibida: 114 -> [('P', 1413.0)]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	2659.0714285714284
# 10	2386.0
# 100	4516.0
# 101	3468.0
# 104	3771.0
# 105	2170.0
# 106	2388.5
# 11	2636.5
# 112	4743.0
# 114	1413.0
# ... [más resultados omitidos]
# [DEBUG] Leídos 106 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_pp
# [OK] Job 2 completado | Jugadores con PP calculado: 106
#
# ========== INICIANDO JOB 3: PUNTAJE HEROICO ==========
#
# ---- Iteración 1 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 0.7994987468671679
# [Map] 65 -> 0.6037322012912354
# [Map] 82 -> 1.3911147451621695
# [Map] 63 -> 0.5953836726356642
# [Map] 76 -> 1.270287486844292
# [Map] 66 -> 1.0855765779623647
# [Map] 29 -> 0.7220290950311733
# [Map] 98 -> 1.0780516748476185
# [Map] 31 -> 0.4934465854156737
# [Map] 86 -> 1.1763929472705539
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [0.9403026544003323, 0.8955256194370941, 0.8900657501494321, 0.7838088219812611, 1.2908809998998252, 1.343643976034072, 0.8955256194370941, 2.415142078629817, 0.928266663711371, 1.3892745185848634, '...']
# [Reduce] Clave recibida: 4 -> [1.0263129082880187, 1.3178686911289188]
# [Reduce] Clave recibida: 5 -> [0.9634650905060953]
# [Reduce] Clave recibida: 8 -> [1.2644236493082839, 0.9648243032086922, 0.9473618482672495, 1.159584225007643]
# [Reduce] Clave recibida: 9 -> [0.31497643567812883, 0.42984242684103335, 0.407369782046546, 0.349967029983321, 0.38884848484848483, 0.41692659596589726]
# [Reduce] Clave recibida: 10 -> [2.1671207992733876, 0.9435802794621672, 0.839872]
# [Reduce] Clave recibida: 11 -> [0.8825104602510461]
# [Reduce] Clave recibida: 12 -> [1.2302622083233101, 1.3342741399920308, 3.177903436276642]
# [Reduce] Clave recibida: 13 -> [0.5411663577510947, 0.481673640167364, 0.8004227389031038]
# [Reduce] Clave recibida: 14 -> [1.6370007787295584, 1.4287178380710934, 1.0746541161196088]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	6.348302759045847
# 4	1.2715246830822213
# 5	0.9926199482822313
# 8	1.6739111932099577
# 9	1.264202012583409
# 10	1.596015761904582
# 11	0.9762671129707113
# 12	1.9579728364875808
# 13	1.1662990728379556
# 14	1.6343552920498927
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 1 | Diferencia promedio Δ=1.0117
#
# ---- Iteración 2 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 1.3514047637651934
# [Map] 65 -> 1.7788617721795907
# [Map] 82 -> 1.8234066042230286
# [Map] 63 -> 2.930696398377532
# [Map] 76 -> 2.4464091093808484
# [Map] 66 -> 2.6813947717600857
# [Map] 29 -> 1.2950434089281329
# [Map] 98 -> 2.285527652504194
# [Map] 31 -> 2.428924737333787
# [Map] 86 -> 3.504830397641376
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [1.6370358559571148, 3.4347766792654513, 1.6669272598064508, 2.736737292097192, 3.2092746206023324, 3.4347766792654513, 3.712050251369395, 3.4271517825188114, 1.5512730153546443, 2.1896692193547045, '...']
# [Reduce] Clave recibida: 4 -> [2.5220168656212354, 1.3081427520311593]
# [Reduce] Clave recibida: 5 -> [2.7288506008925406]
# [Reduce] Clave recibida: 8 -> [1.9351414101117548, 2.1969699684781223, 2.2515763485849662, 2.711301815726549]
# [Reduce] Clave recibida: 9 -> [0.7087949925857006, 0.8772580655285366, 1.1538054522964032, 1.2920749796559357, 0.697158238214784, 0.755842366646706]
# [Reduce] Clave recibida: 10 -> [3.330843919648193, 1.5794695914839016, 2.3744188761534026]
# [Reduce] Clave recibida: 11 -> [1.6527776099797435]
# [Reduce] Clave recibida: 12 -> [4.718654442501242, 3.975206222955506, 4.05985458437967]
# [Reduce] Clave recibida: 13 -> [3.435487882014066, 0.9020849538254696, 2.2462566801523636]
# [Reduce] Clave recibida: 14 -> [4.59397735211147, 3.0289588177663656, 3.2253664366306465]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	10.43459485419332
# 4	1.5716922427657838
# 5	1.3492278213802933
# 8	2.6351878876660813
# 9	1.9059566871754694
# 10	2.2695159422316706
# 11	1.1318610772159083
# 12	3.3742504804669564
# 13	2.127933562230364
# 14	2.989357126514714
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 2 | Diferencia promedio Δ=1.2748
#
# ---- Iteración 3 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 2.690283908185741
# [Map] 65 -> 3.385441542094009
# [Map] 82 -> 2.0901111226657987
# [Map] 63 -> 4.637845626437214
# [Map] 76 -> 4.654249960940543
# [Map] 66 -> 4.152544391186979
# [Map] 29 -> 1.9841291570159993
# [Map] 98 -> 4.552389864031301
# [Map] 31 -> 3.8437887923925134
# [Map] 86 -> 6.392162681561447
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [1.992801529263422, 3.9823413754399986, 2.923085150754268, 5.45112420556761, 5.101203617832029, 3.9823413754399986, 6.997395939613994, 7.106251816313406, 2.10609127338888, 2.7887766656622017, '...']
# [Reduce] Clave recibida: 4 -> [5.146258566159922, 1.7781051029971697]
# [Reduce] Clave recibida: 5 -> [4.26906242522091]
# [Reduce] Clave recibida: 8 -> [2.1613314861930673, 3.126931622127236, 3.9586777884046684, 4.529220683437937]
# [Reduce] Clave recibida: 9 -> [1.4792640682637255, 1.1729341628321581, 1.8050337753201022, 2.679137299324647, 1.2509331772513699, 1.111884654960911]
# [Reduce] Clave recibida: 10 -> [6.278803394495013, 2.486511323479279, 4.283050945733846]
# [Reduce] Clave recibida: 11 -> [2.898272651556419]
# [Reduce] Clave recibida: 12 -> [5.4708921649005395, 7.250041225100976, 6.322746460724976]
# [Reduce] Clave recibida: 13 -> [5.646851691852113, 1.5818753444299969, 3.7955976413830297]
# [Reduce] Clave recibida: 14 -> [7.762643404162791, 6.03318074294992, 6.219709898382438]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	14.960138047592057
# 4	2.1967214611697328
# 5	1.660350609894624
# 8	3.580784639192908
# 9	2.7168358018664884
# 10	3.433769864069044
# 11	1.3834510756143967
# 12	4.644823329846751
# 13	3.0249135848883584
# 14	4.84113787719002
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 3 | Diferencia promedio Δ=1.5704
#
# ---- Iteración 4 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 3.6153891833353455
# [Map] 65 -> 5.209805591896149
# [Map] 82 -> 2.3586146322640995
# [Map] 63 -> 7.053654115217188
# [Map] 76 -> 6.461699534498477
# [Map] 66 -> 5.814811270027624
# [Map] 29 -> 2.877251969491411
# [Map] 98 -> 7.323704842420859
# [Map] 31 -> 5.845980831904734
# [Map] 86 -> 9.918846651264992
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [2.542619844987856, 6.36881708877467, 4.827466916627467, 8.769553121182012, 7.374887852200049, 6.36881708877467, 9.542365643931433, 10.236465322109797, 2.8307490923537353, 3.7093599376086326, '...']
# [Reduce] Clave recibida: 4 -> [8.126987370128983, 2.18812408507693]
# [Reduce] Clave recibida: 5 -> [6.453477586712738]
# [Reduce] Clave recibida: 8 -> [3.0932315027339343, 4.606045608882259, 5.248732914457661, 7.291956906528587]
# [Reduce] Clave recibida: 9 -> [2.4297605080598395, 1.6389409845885257, 2.7286424633823367, 3.8592631905823995, 1.7331976432206133, 1.665992705116032]
# [Reduce] Clave recibida: 10 -> [8.562419264777866, 3.3787577705434795, 6.837204734248621]
# [Reduce] Clave recibida: 11 -> [4.786489143891165]
# [Reduce] Clave recibida: 12 -> [8.749403485484034, 11.25003394149531, 8.55658254221127]
# [Reduce] Clave recibida: 13 -> [8.095923418668967, 2.612462688435193, 6.201786054742726]
# [Reduce] Clave recibida: 14 -> [12.68370838020003, 9.705942667927614, 10.663244978139142]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	21.186847830658195
# 4	2.881652513951595
# 5	2.101602472515973
# 8	4.886473320385694
# 9	3.637271093979849
# 10	4.591233117453134
# 11	1.7648708070660155
# 12	6.566316033776505
# 13	4.213854776693072
# 14	7.474684997305891
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 4 | Diferencia promedio Δ=1.9454
#
# ---- Iteración 5 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 5.013815589247575
# [Map] 65 -> 7.7336305555191345
# [Map] 82 -> 2.8507008837815513
# [Map] 63 -> 9.836120396549015
# [Map] 76 -> 9.032147709657771
# [Map] 66 -> 8.060627003417297
# [Map] 29 -> 3.9934755011933594
# [Map] 98 -> 10.5435647493708
# [Map] 31 -> 8.152054291190916
# [Map] 86 -> 14.541220844640723
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [3.076038408120809, 9.195943869959299, 6.922014982142117, 12.625078856354595, 10.05026912022215, 9.195943869959299, 13.291198954659007, 14.996728080748188, 3.5852275999982828, 4.90109350760854, '...']
# [Reduce] Clave recibida: 4 -> [11.395596032235146, 2.7696360997279252]
# [Reduce] Clave recibida: 5 -> [9.179714689806532]
# [Reduce] Clave recibida: 8 -> [4.10289255697431, 6.111423645756121, 7.0480959695503085, 10.59606185136727]
# [Reduce] Clave recibida: 9 -> [3.434011340853405, 2.1892735158706556, 3.8813428833956345, 5.653936084382325, 2.3945166198516077, 2.298394463125932]
# [Reduce] Clave recibida: 10 -> [11.92626883394927, 4.610779861233957, 10.265612051089773]
# [Reduce] Clave recibida: 11 -> [6.863257716330827]
# [Reduce] Clave recibida: 12 -> [12.633275885713555, 16.49276713357838, 11.407224638492837]
# [Reduce] Clave recibida: 13 -> [11.465609272743977, 3.745961636184358, 9.139434601230324]
# [Reduce] Clave recibida: 14 -> [18.691699813357083, 13.973151181656378, 15.895359992295017]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	28.90286573517072
# 4	3.6593768906565405
# 5	2.6523023673409196
# 8	6.425411752776899
# 9	4.8079979313108705
# 10	6.212137470747146
# 11	2.184378058698827
# 12	8.985720066872524
# 13	5.716903113052049
# 14	10.607162619436314
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 5 | Diferencia promedio Δ=2.4235
#
# ---- Iteración 6 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 6.786377917624264
# [Map] 65 -> 10.671921571659983
# [Map] 82 -> 3.454516167106668
# [Map] 63 -> 13.43375926348141
# [Map] 76 -> 12.019984870427683
# [Map] 66 -> 10.740266642232756
# [Map] 29 -> 5.375958000059741
# [Map] 98 -> 14.61936513722182
# [Map] 31 -> 11.13373265430054
# [Map] 86 -> 19.96252071322296
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [3.7931046865295004, 12.632189206483089, 9.674379401269082, 17.505525130699386, 13.401992180001162, 12.632189206483089, 17.88535702599012, 20.7698581343793, 4.5952815848437165, 6.464956230645756, '...']
# [Reduce] Clave recibida: 4 -> [15.567263764808924, 3.4953862493257106]
# [Reduce] Clave recibida: 5 -> [12.616138502974332]
# [Reduce] Clave recibida: 8 -> [5.321781263447023, 8.085400127085242, 9.299990237632914, 14.813877697104171]
# [Reduce] Clave recibida: 9 -> [4.727350344246958, 2.9012516225601566, 5.334322585082989, 7.830471402906855, 3.244772786169232, 3.014244346633605]
# [Reduce] Clave recibida: 10 -> [16.04863314519499, 6.0628918173447195, 14.39735057208659]
# [Reduce] Clave recibida: 11 -> [9.5922587928182]
# [Reduce] Clave recibida: 12 -> [17.353947951700597, 22.64164811469486, 15.053842874660717]
# [Reduce] Clave recibida: 13 -> [15.641258578471254, 5.235448664087005, 12.620910567473324]
# [Reduce] Clave recibida: 14 -> [25.81191091040583, 19.37471852244543, 22.555230153354156]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	38.58993215816536
# 4	4.648655302855197
# 5	3.3464599776008153
# 8	8.377251963704408
# 9	6.262587443695159
# 10	8.172792857994512
# 11	2.7356362761492763
# 12	11.917986666093348
# 13	7.564518797626381
# 14	14.481855636413496
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 6 | Diferencia promedio Δ=3.0168
#
# ---- Iteración 7 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 8.958574484870242
# [Map] 65 -> 14.350757521586099
# [Map] 82 -> 4.177423058643598
# [Map] 63 -> 17.904721947247033
# [Map] 76 -> 15.760396755530916
# [Map] 66 -> 14.10257909719384
# [Map] 29 -> 7.0639955893949145
# [Map] 98 -> 19.698791114909174
# [Map] 31 -> 14.839210938679164
# [Map] 86 -> 26.84893905780684
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [4.69624155423775, 16.978086550965003, 13.070355664594159, 23.587733097141264, 17.569619060092894, 16.978086550965003, 23.55873650394203, 27.91826202073213, 5.871218146422447, 8.346201841333164, '...']
# [Reduce] Clave recibida: 4 -> [20.73653450626405, 4.410194830596097]
# [Reduce] Clave recibida: 5 -> [16.865969763324806]
# [Reduce] Clave recibida: 8 -> [6.853556559874083, 10.430207600518887, 12.132525193965543, 20.064489533493017]
# [Reduce] Clave recibida: 9 -> [6.325420866766244, 3.7655538924047787, 7.131225089722951, 10.525500509333963, 4.306808664404223, 3.9724784731634863]
# [Reduce] Clave recibida: 10 -> [21.139388996633613, 7.904609749037194, 19.52961194029783]
# [Reduce] Clave recibida: 11 -> [12.959408438387058]
# [Reduce] Clave recibida: 12 -> [23.324288886814738, 30.452278003001904, 19.604555936107143]
# [Reduce] Clave recibida: 13 -> [20.883573031896187, 7.073236769519809, 17.02793596320041]
# [Reduce] Clave recibida: 14 -> [34.8250281721326, 26.106368470959634, 30.770566157060514]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	50.62766053728138
# 4	5.87763932604575
# 5	4.204925892191611
# 8	10.79311733534601
# 9	8.075451474150722
# 10	10.609869358565664
# 11	3.415800504554186
# 12	15.620986810836605
# 13	9.884918644452515
# 14	19.321796485630855
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 7 | Diferencia promedio Δ=3.7553
#
# ---- Iteración 8 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 11.701848600552847
# [Map] 65 -> 18.916221652565532
# [Map] 82 -> 5.076295575535847
# [Map] 63 -> 23.441266859638148
# [Map] 76 -> 20.435640244319995
# [Map] 66 -> 18.27025112319457
# [Map] 29 -> 9.186471230941562
# [Map] 98 -> 26.04317410274871
# [Map] 31 -> 19.42783052565214
# [Map] 86 -> 35.36858057445829
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [5.813308334199292, 22.38613683982426, 17.299939567411865, 31.184626313087865, 22.74788797828637, 22.38613683982426, 30.622959236187214, 36.810753124701975, 7.443576856155212, 10.68889603757269, '...']
# [Reduce] Clave recibida: 4 -> [27.18416495945918, 5.541540181836659]
# [Reduce] Clave recibida: 5 -> [22.150348838396678]
# [Reduce] Clave recibida: 8 -> [8.757981525314992, 13.381325476767236, 15.654899245712812, 26.586114260348364]
# [Reduce] Clave recibida: 9 -> [8.326578717634387, 4.8418656784569025, 9.365552387386195, 13.87807022067833, 5.617142938170029, 5.147330512703982]
# [Reduce] Clave recibida: 10 -> [27.478156454336844, 10.184172671553748, 25.955734944507412]
# [Reduce] Clave recibida: 11 -> [17.153089676115172]
# [Reduce] Clave recibida: 12 -> [30.75380262342634, 40.11532246790224, 25.305426975217202]
# [Reduce] Clave recibida: 13 -> [27.39798665441939, 9.362145285010328, 22.493157203475786]
# [Reduce] Clave recibida: 14 -> [46.00233610134068, 34.514437729385826, 41.04088508674112]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	65.60562767269204
# 4	7.40859243854176
# 5	5.272370465356129
# 8	13.802824742644967
# 9	10.327661171916025
# 10	13.648848942220399
# 11	4.262924114575265
# 12	20.225259517442247
# 13	12.767164406866913
# 14	25.352647101328458
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 8 | Diferencia promedio Δ=4.6744
#
# ---- Iteración 9 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 15.106650838094577
# [Map] 65 -> 24.583924432001353
# [Map] 82 -> 6.201066918715057
# [Map] 63 -> 30.33634877346497
# [Map] 76 -> 26.240140485928624
# [Map] 66 -> 23.474780951931624
# [Map] 29 -> 11.82203764619733
# [Map] 98 -> 33.934221821262526
# [Map] 31 -> 25.142388688588582
# [Map] 86 -> 45.99820830853787
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [7.203927470583295, 29.10416117239736, 22.564408607937143, 40.63352733220848, 29.187362095639642, 29.10416117239736, 39.388647944888696, 47.89136088693071, 9.410568148693574, 13.600484679082708, '...']
# [Reduce] Clave recibida: 4 -> [35.20448789461491, 6.948291964325651]
# [Reduce] Clave recibida: 5 -> [28.72918813966155]
# [Reduce] Clave recibida: 8 -> [11.14313947885382, 17.0620426793122, 20.044987078111486, 34.697115733229765]
# [Reduce] Clave recibida: 9 -> [10.814914195166162, 6.181916672314799, 12.147199962045846, 18.055584657589183, 7.249433884356193, 6.610817802264647]
# [Reduce] Clave recibida: 10 -> [35.34365906334279, 13.024073228032254, 33.93816826064443]
# [Reduce] Clave recibida: 11 -> [22.37287146768657]
# [Reduce] Clave recibida: 12 -> [39.982942774834015, 52.17152990796828, 32.39439895169454]
# [Reduce] Clave recibida: 13 -> [35.503558575605176, 12.211098821164791, 29.308162539162442]
# [Reduce] Clave recibida: 14 -> [59.9401823160216, 44.97226725606827, 53.8130510919297]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	84.23578539594598
# 4	9.312861531505993
# 5	6.601296004211633
# 8	17.553351563840472
# 9	13.13209316909484
# 10	17.423791911507934
# 11	5.317320036472688
# 12	25.95687207016836
# 13	16.356609627058347
# 14	32.86055113413195
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 9 | Diferencia promedio Δ=5.8169
#
# ---- Iteración 10 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 19.34246329595271
# [Map] 65 -> 31.64174870289624
# [Map] 82 -> 7.602558217366064
# [Map] 63 -> 38.91522240544545
# [Map] 76 -> 33.460134195775545
# [Map] 66 -> 29.94084519481482
# [Map] 29 -> 15.105566918058416
# [Map] 98 -> 43.758366235342564
# [Map] 31 -> 32.252452492779895
# [Map] 86 -> 59.22433153324799
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [8.93616335062043, 37.47190294670059, 29.117847082426078, 52.39715764816758, 37.209480763141634, 37.47190294670059, 50.313410639893185, 61.67809303521746, 11.85645670589337, 17.219255153029973, '...']
# [Reduce] Clave recibida: 4 -> [45.17835702875639, 8.699641324824947]
# [Reduce] Clave recibida: 5 -> [36.91971386257545]
# [Reduce] Clave recibida: 8 -> [14.107669293612195, 21.635136797577914, 25.50145378841918, 44.792790182452585]
# [Reduce] Clave recibida: 9 -> [13.908208038213242, 7.85189694485992, 15.610296561464313, 23.253338591594193, 9.28278605233286, 8.43238559651863]
# [Reduce] Clave recibida: 10 -> [45.1465111079322, 16.562996374106262, 43.87207612478408]
# [Reduce] Clave recibida: 11 -> [28.870681324292292]
# [Reduce] Clave recibida: 12 -> [51.47844469068583, 67.17270297010165, 41.21739297324904]
# [Reduce] Clave recibida: 13 -> [45.58557317502694, 15.757599251149859, 37.78519222582987]
# [Reduce] Clave recibida: 14 -> [77.27715129994255, 57.99198671447606, 69.72473257544337]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	107.42885863228929
# 4	11.68135566742343
# 5	8.25578220024024
# 8	22.217484112536496
# 9	16.6224601805666
# 10	22.125479888578155
# 11	6.629877627507043
# 12	33.09144520807538
# 13	20.821929659705347
# 14	42.206761859152124
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 10 | Diferencia promedio Δ=7.2387
#
# ---- Iteración 11 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 24.614511711191096
# [Map] 65 -> 40.42305443042394
# [Map] 82 -> 9.346103278626446
# [Map] 63 -> 49.594218763695494
# [Map] 76 -> 42.44951423002341
# [Map] 66 -> 37.98739522179694
# [Map] 29 -> 19.189899481013665
# [Map] 98 -> 55.98219172178483
# [Map] 31 -> 41.10307190146747
# [Map] 86 -> 75.67948982032588
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [11.092317711624283, 47.88333035310955, 37.27166351288788, 67.0342148827106, 47.1888459566024, 47.88333035310955, 63.904728844143214, 78.8337850002902, 14.900670111159211, 21.72563768609196, '...']
# [Reduce] Clave recibida: 4 -> [57.58587945301422, 10.88003688247603]
# [Reduce] Clave recibida: 5 -> [47.110638231738356]
# [Reduce] Clave recibida: 8 -> [17.797504985446505, 27.324917446457015, 32.29438590066033, 57.35696907420156]
# [Reduce] Clave recibida: 9 -> [17.75813785462608, 9.93020107544585, 19.919196468712656, 29.72122847608115, 11.812267023222404, 10.698784555610988]
# [Reduce] Clave recibida: 10 -> [57.3420786609117, 20.963979867853446, 56.23938433311017]
# [Reduce] Clave recibida: 11 -> [36.95528438832581]
# [Reduce] Clave recibida: 12 -> [65.78153708111662, 85.83627301518294, 52.193035623206924]
# [Reduce] Clave recibida: 13 -> [58.13688414339324, 20.170170390593906, 48.33453698121699]
# [Reduce] Clave recibida: 14 -> [98.85235742579682, 74.19194997172595, 89.51886537573466]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	136.2896407405906
# 4	14.628115099769031
# 5	10.31434892281115
# 8	28.02230303616662
# 9	20.965642721647228
# 10	27.97617945809882
# 11	8.262967446441813
# 12	41.96779083534032
# 13	26.379601486071238
# 14	53.835760900198004
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 11 | Diferencia promedio Δ=9.0083
#
# ---- Iteración 12 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 31.17618852646177
# [Map] 65 -> 51.35179593340374
# [Map] 82 -> 11.516456668650644
# [Map] 63 -> 62.881897324022525
# [Map] 76 -> 53.63560841893992
# [Map] 66 -> 48.002696312324716
# [Map] 29 -> 24.272926463819996
# [Map] 98 -> 71.19503584641032
# [Map] 31 -> 52.11573468522966
# [Map] 86 -> 96.15598716862456
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [13.775997278799665, 60.83989534685866, 47.418754748515816, 85.25038382256457, 59.61076253452771, 60.83989534685866, 80.81792386849092, 100.18325388843267, 18.68886143722554, 27.33181430170739, '...']
# [Reduce] Clave recibida: 4 -> [73.03084146806812, 13.592957514752102]
# [Reduce] Clave recibida: 5 -> [59.79421459178622]
# [Reduce] Clave recibida: 8 -> [22.389161743364753, 34.407426999638986, 40.74711151320129, 72.99200546625461]
# [Reduce] Clave recibida: 9 -> [22.549411354882967, 12.516699119583425, 25.282032951609317, 37.77021968797251, 14.960594271973722, 13.51942728532849]
# [Reduce] Clave recibida: 10 -> [72.51838528227015, 26.441292530039632, 71.62735365892699]
# [Reduce] Clave recibida: 11 -> [47.0162424187409]
# [Reduce] Clave recibida: 12 -> [83.58110854565358, 109.06087747480727, 65.8539573969095]
# [Reduce] Clave recibida: 13 -> [73.75536847879063, 25.66143479634673, 61.46338704570697]
# [Reduce] Clave recibida: 14 -> [125.70309108791913, 94.3531929582643, 114.15338602342953]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	172.20539435837637
# 4	18.29600739452969
# 5	12.876431347540818
# 8	35.24621255593685
# 9	26.370873703612787
# 10	35.25658035718983
# 11	10.295280968585663
# 12	53.01418057030881
# 13	33.29579844481056
# 14	68.30835335406182
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 12 | Diferencia promedio Δ=11.2105
#
# ---- Iteración 13 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 39.34175396988724
# [Map] 65 -> 64.95223187688856
# [Map] 82 -> 14.216892881693726
# [Map] 63 -> 79.41894199806272
# [Map] 76 -> 67.5565311787177
# [Map] 66 -> 60.46578572171562
# [Map] 29 -> 30.598999433986883
# [Map] 98 -> 90.12658008460112
# [Map] 31 -> 65.82143170434335
# [Map] 86 -> 121.6401081864932
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [17.11565396846546, 76.96392221074103, 60.0465954110123, 107.91939990595208, 75.06725287808315, 76.96392221074103, 101.86541502707858, 126.75072551908208, 23.403657416943517, 34.308601134681425, '...']
# [Reduce] Clave recibida: 4 -> [92.25026415522046, 16.969445726394998]
# [Reduce] Clave recibida: 5 -> [75.57753519567632]
# [Reduce] Clave recibida: 8 -> [28.103371567734165, 43.22104633170556, 51.266880243853834, 92.44950587323063]
# [Reduce] Clave recibida: 9 -> [28.512175900928565, 15.735181825972523, 31.95549516392472, 47.78645694416195, 18.878285395892238, 17.029716011467055]
# [Reduce] Clave recibida: 10 -> [91.40441946878698, 33.25763109351384, 90.77842195606303]
# [Reduce] Clave recibida: 11 -> [59.536892127108686]
# [Reduce] Clave recibida: 12 -> [105.7321006178773, 137.9651681146502, 82.85443516782628]
# [Reduce] Clave recibida: 13 -> [93.19176605001344, 32.49519733393112, 77.80141296943134]
# [Reduce] Clave recibida: 14 -> [159.11713576722477, 119.44274625742169, 144.809980821496]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	216.90057024404317
# 4	22.860381396086325
# 5	16.064662109526616
# 8	44.23624241133789
# 9	33.09725687095411
# 10	44.3169754487095
# 11	12.824452209675956
# 12	66.76144418787148
# 13	41.90265202338193
# 14	86.31871229492079
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 13 | Diferencia promedio Δ=13.9510
#
# ---- Iteración 14 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 49.503362592679245
# [Map] 65 -> 81.87752927001988
# [Map] 82 -> 17.57752975819376
# [Map] 63 -> 99.99785260146874
# [Map] 76 -> 84.8803556230392
# [Map] 66 -> 75.97597805450467
# [Map] 29 -> 38.471134746145204
# [Map] 98 -> 113.68609432563224
# [Map] 31 -> 82.87697695279199
# [Map] 86 -> 153.35368556879294
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [21.271694799997153, 97.02963375167145, 75.7608455853154, 136.13004139019745, 94.30313667675681, 97.02963375167145, 128.05843807274417, 159.81320493283002, 29.270782221152217, 42.99106174690305, '...']
# [Reduce] Clave recibida: 4 -> [116.16830767031772, 21.171115227710178]
# [Reduce] Clave recibida: 5 -> [95.21925514378583]
# [Reduce] Clave recibida: 8 -> [35.214431429997184, 54.189463765161456, 64.35767861192066, 116.66304594518168]
# [Reduce] Clave recibida: 9 -> [35.932419318993034, 19.740558719989508, 40.2603556649706, 60.251385586597614, 23.75372392319635, 21.398005360367165]
# [Reduce] Clave recibida: 10 -> [114.90756884470804, 41.74044597684638, 114.61078836492914]
# [Reduce] Clave recibida: 11 -> [75.11775247534254]
# [Reduce] Clave recibida: 12 -> [133.29813117704842, 173.9349571940699, 104.01056200881662]
# [Reduce] Clave recibida: 13 -> [117.3792915931043, 40.99922086554823, 98.13370598412997]
# [Reduce] Clave recibida: 14 -> [200.70013669999622, 150.6656449716312, 182.96127388177658]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	272.52202050786263
# 4	28.540563425401636
# 5	20.03228953904474
# 8	55.42377318995673
# 9	41.46796261197109
# 10	55.59227824366968
# 11	15.971786000019195
# 12	83.86921737674687
# 13	52.613468125442076
# 14	108.73206522178761
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 14 | Diferencia promedio Δ=17.3614
#
# ---- Iteración 15 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 62.14899189919348
# [Map] 65 -> 102.94030412119817
# [Map] 82 -> 21.75975310009448
# [Map] 63 -> 125.60768855418115
# [Map] 76 -> 106.43900655738469
# [Map] 66 -> 95.27759771538277
# [Map] 29 -> 48.267917504722604
# [Map] 98 -> 143.00490264180672
# [Map] 31 -> 104.1020905807476
# [Map] 86 -> 192.81996028974737
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [26.44364586829686, 122.00044719134192, 95.31684536911784, 171.23697872731933, 118.24102438289033, 122.00044719134192, 160.65455207019096, 200.95816915087062, 36.5721552101871, 53.79608912317159, '...']
# [Reduce] Clave recibida: 4 -> [145.9330367932794, 26.399927195136424]
# [Reduce] Clave recibida: 5 -> [119.66267296685828]
# [Reduce] Clave recibida: 8 -> [44.063855906941484, 67.83909591403736, 80.6487445290607, 146.79598011290992]
# [Reduce] Clave recibida: 9 -> [45.16662433978688, 24.725088747303467, 50.595457464898956, 75.76350240504121, 29.821024212269375, 26.834151562752943]
# [Reduce] Clave recibida: 10 -> [144.1562483507309, 52.29677939542714, 144.26915527425226]
# [Reduce] Clave recibida: 11 -> [94.50775188490904]
# [Reduce] Clave recibida: 12 -> [167.60273108925264, 218.69791661521296, 130.33835442050326]
# [Reduce] Clave recibida: 13 -> [147.47974924520915, 51.582270040729796, 123.43620015837979]
# [Reduce] Clave recibida: 14 -> [252.44804521619997, 189.52120765903808, 230.4387889599908]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	341.7405410274076
# 4	35.60925872566
# 5	24.969859939305373
# 8	69.3462306455158
# 9	51.88498144387468
# 10	69.62388097012288
# 11	19.888565880751628
# 12	105.15907842924372
# 13	65.9426403277524
# 14	136.62442445071625
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 15 | Diferencia promedio Δ=21.6055
#
# ---- Iteración 16 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 77.8859551805352
# [Map] 65 -> 129.1520594741346
# [Map] 82 -> 26.964316007955457
# [Map] 63 -> 157.47806045789162
# [Map] 76 -> 133.26787029254797
# [Map] 66 -> 119.29764644483794
# [Map] 29 -> 60.45949226209237
# [Map] 98 -> 179.4909134475758
# [Map] 31 -> 130.51585856702062
# [Map] 86 -> 241.93398381990008
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [32.879948762033635, 153.07559997742305, 119.65341925820562, 214.92607008554612, 148.03075218368792, 153.07559997742305, 201.2190839140622, 252.1612089291529, 45.658416467444816, 67.24245810313249, '...']
# [Reduce] Clave recibida: 4 -> [182.9740741360158, 32.906996635884795]
# [Reduce] Clave recibida: 5 -> [150.08144070908227]
# [Reduce] Clave recibida: 8 -> [55.076542833274026, 84.82543493757755, 100.92227574829697, 184.2950846513427]
# [Reduce] Clave recibida: 9 -> [56.65816457374589, 30.928111826331882, 63.45704104211513, 95.0676274564338, 37.37154352856561, 33.59921074323898]
# [Reduce] Clave recibida: 10 -> [180.5550347614724, 65.4337356921437, 181.17772722636826]
# [Reduce] Clave recibida: 11 -> [118.63774567490337]
# [Reduce] Clave recibida: 12 -> [210.29339817995995, 274.4034286716122, 163.10214783015866]
# [Reduce] Clave recibida: 13 -> [184.93848388369068, 64.75240509242782, 154.92413484664345]
# [Reduce] Clave recibida: 14 -> [316.84623269886845, 237.87530393705296, 289.52249177030836]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	427.8800440464433
# 4	44.40597629592392
# 5	31.114451023234622
# 8	86.67210631043923
# 9	64.84850323242713
# 10	87.08563253135684
# 11	24.762824626330485
# 12	131.65339288570962
# 13	82.53023481219792
# 14	171.33529373805843
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 16 | Diferencia promedio Δ=26.8872
#
# ---- Iteración 17 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 97.4699385072548
# [Map] 65 -> 161.77145961243767
# [Map] 82 -> 33.44117571415437
# [Map] 63 -> 197.1393573936293
# [Map] 76 -> 166.6552554145871
# [Map] 66 -> 149.18956115879922
# [Map] 29 -> 75.63141753477389
# [Map] 98 -> 224.89618960288402
# [Map] 31 -> 163.38664835448745
# [Map] 86 -> 303.05429759325506
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [40.88964622456969, 191.74731335865619, 149.939243169837, 269.29527116524093, 185.10279848895954, 191.74731335865619, 251.69988893823154, 315.88123789123273, 56.96588056666316, 83.97589046195998, '...']
# [Reduce] Clave recibida: 4 -> [229.07005019237124, 41.00476084518506]
# [Reduce] Clave recibida: 5 -> [187.93630727750008]
# [Reduce] Clave recibida: 8 -> [68.78138012046792, 105.96422269170199, 126.15183493662133, 230.96115013452314]
# [Reduce] Clave recibida: 9 -> [70.95891173970222, 38.64750451858544, 79.46273641741621, 119.09079898470065, 46.76783063523461, 42.01804181346188]
# [Reduce] Clave recibida: 10 -> [225.85174980773863, 81.78209029397891, 227.10888255341357]
# [Reduce] Clave recibida: 11 -> [148.66648950068105]
# [Reduce] Clave recibida: 12 -> [263.42012785850045, 343.7265696214114, 203.87532364800515]
# [Reduce] Clave recibida: 13 -> [231.55428499099168, 81.14207411017638, 194.10951562857738]
# [Reduce] Clave recibida: 14 -> [396.98700798811905, 298.04990363312265, 363.0496750057466]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	535.0769922044458
# 4	55.353111829586375
# 5	38.76113407005502
# 8	108.23343475242952
# 9	80.98105647003841
# 10	108.81602997633648
# 11	30.828630879137577
# 12	164.62444826783926
# 13	103.17278669540859
# 14	214.53149049865164
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 17 | Diferencia promedio Δ=33.4599
#
# ---- Iteración 18 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 121.84137245795506
# [Map] 65 -> 202.3649177259201
# [Map] 82 -> 41.50135361260942
# [Map] 63 -> 246.49615219862105
# [Map] 76 -> 208.20443203275556
# [Map] 66 -> 186.38878852012573
# [Map] 29 -> 94.51222744160445
# [Map] 98 -> 281.4011256056221
# [Map] 31 -> 204.2929462308971
# [Map] 86 -> 379.1159427599793
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [50.85737156180312, 239.87259729679872, 187.6286644278933, 336.95543068106406, 231.23736553988329, 239.87259729679872, 314.5211056569611, 395.17811989521266, 71.03754010752698, 104.79993644193632, '...']
# [Reduce] Clave recibida: 4 -> [286.4345302313149, 51.08208502357595]
# [Reduce] Clave recibida: 5 -> [235.04506777325253]
# [Reduce] Clave recibida: 8 -> [85.83646328160407, 132.2705441069632, 157.54895395169083, 289.03508070046803]
# [Reduce] Clave recibida: 9 -> [88.75558736868894, 48.253958723945345, 99.38113894672529, 148.98662026833506, 58.46111107276676, 52.49491904603856]
# [Reduce] Clave recibida: 10 -> [282.22158684194613, 102.12693461084768, 284.2682608670708]
# [Reduce] Clave recibida: 11 -> [186.03598551314826]
# [Reduce] Clave recibida: 12 -> [329.5340578331018, 429.99628623836196, 254.6158002145749]
# [Reduce] Clave recibida: 13 -> [289.5656669876908, 101.5383209381454, 242.87406844847325]
# [Reduce] Clave recibida: 14 -> [496.7188210172737, 372.93463494026383, 454.5511261345164]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	668.4790233099864
# 4	68.97635628148795
# 5	48.277103690197016
# 8	135.0655904922267
# 9	101.057333756153
# 10	135.85859002861267
# 11	38.37726907365595
# 12	205.65552114577983
# 13	128.86156738761053
# 14	268.2873255825949
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 18 | Diferencia promedio Δ=41.6395
#
# ---- Iteración 19 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 152.17058215734778
# [Map] 65 -> 252.88174430244095
# [Map] 82 -> 51.53190150515071
# [Map] 63 -> 307.9185836425121
# [Map] 76 -> 259.9106069561367
# [Map] 66 -> 232.68164659329184
# [Map] 29 -> 118.00859256072452
# [Map] 98 -> 351.71912095703453
# [Map] 31 -> 255.19909374035907
# [Map] 86 -> 473.77142340578183
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [63.2617828221005, 299.76247551923257, 234.53154940127575, 421.155628378464, 288.6498816122103, 299.76247551923257, 392.6994370560804, 493.85970873225114, 88.54911934057534, 130.71457447890072, '...']
# [Reduce] Clave recibida: 4 -> [357.8221890208393, 63.62288345169504]
# [Reduce] Clave recibida: 5 -> [293.6699200650406]
# [Reduce] Clave recibida: 8 -> [107.06078989290701, 165.0076443811131, 196.62132422396652, 361.3056147590008]
# [Reduce] Clave recibida: 9 -> [110.90278880701125, 60.208784193228, 124.16874519831431, 186.19069524960767, 73.01290031764748, 65.53294628133996]
# [Reduce] Clave recibida: 10 -> [352.37145070570585, 127.4452276223779, 355.40066743172184]
# [Reduce] Clave recibida: 11 -> [232.54073709808716]
# [Reduce] Clave recibida: 12 -> [411.81004440337904, 537.3552774047414, 317.76017045143254]
# [Reduce] Clave recibida: 13 -> [361.75835827767446, 126.92058436720933, 303.55947154666]
# [Reduce] Clave recibida: 14 -> [620.8308024752052, 466.1255056934341, 568.4208010979248]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	834.4921834860362
# 4	85.92990463945193
# 5	60.11932385313821
# 8	168.4570653979115
# 9	126.04140572952403
# 10	169.51190384348072
# 11	47.771228893813614
# 12	256.71694943642973
# 13	160.83015966669186
# 14	335.18417607184597
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 19 | Diferencia promedio Δ=51.8185
#
# ---- Iteración 20 ----
# [MRE] INICIANDO ETAPA DE MAPEO...
# [Map] 15 -> 189.91399367715485
# [Map] 65 -> 315.7477856378302
# [Map] 82 -> 64.01449185263101
# [Map] 63 -> 384.3561872801474
# [Map] 76 -> 324.25674626325207
# [Map] 66 -> 290.2911351304528
# [Map] 29 -> 147.2488201454789
# [Map] 98 -> 439.22687122854694
# [Map] 31 -> 318.5496292788583
# [Map] 86 -> 591.5661456786605
# ... [más resultados de map omitidos]
# [MRE] INICIANDO ETAPA DE REDUCCIÓN...
# [Reduce] Clave recibida: 1 -> [78.69854393886148, 374.29287764046694, 292.90019391473237, 525.9391882068379, 360.09731122770876, 374.29287764046694, 489.9890463883929, 616.664749777247, 110.34153476075137, 162.96423805908157, '...']
# [Reduce] Clave recibida: 4 -> [446.661083320213, 79.22937463789084]
# [Reduce] Clave recibida: 5 -> [366.6260532387646]
# [Reduce] Clave recibida: 8 -> [133.47356223575954, 205.7475673332575, 245.24522968162574, 451.2432202814196]
# [Reduce] Clave recibida: 9 -> [138.46403849154393, 75.08605615864413, 155.01586603621323, 232.48958452530857, 91.12198325917561, 81.75821731512119]
# [Reduce] Clave recibida: 10 -> [439.66997355569555, 158.9527648455379, 443.9219240588253]
# [Reduce] Clave recibida: 11 -> [290.4139215512044]
# [Reduce] Clave recibida: 12 -> [514.1990047086459, 670.9589785497623, 396.3406485341785]
# [Reduce] Clave recibida: 13 -> [451.5990955088964, 158.50773112542504, 379.07987438974953]
# [Reduce] Clave recibida: 14 -> [775.2828841758394, 582.0975752141761, 710.1267573530357]
# ... [más reduce claves omitidas]
# [MRE] FINALIZANDO Y ESCRIBIENDO RESULTADOS EN DISCO...
#
# [MRE] RESULTADOS FINALES DEL JOB:
# 1	1041.0884948834607
# 4	107.02787250753698
# 5	74.85646275423045
# 8	210.01133506547663
# 9	157.13302064877337
# 10	211.39202181693184
# 11	59.461612153343296
# 12	320.26072362210255
# 13	200.61371360686235
# 14	418.4344577820964
# ... [más resultados omitidos]
# [DEBUG] Leídos 94 resultados desde C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
# [INFO] Iter 20 | Diferencia promedio Δ=64.4860
#
# ========== TOP 10 FINAL ==========
# (Jugador = 1, PH = 1041.09)
# (Jugador = 59, PH = 948.84)
# (Jugador = 47, PH = 828.95)
# (Jugador = 45, PH = 824.89)
# (Jugador = 33, PH = 805.33)
# (Jugador = 77, PH = 762.58)
# (Jugador = 28, PH = 660.50)
# (Jugador = 60, PH = 659.72)
# (Jugador = 51, PH = 652.58)
# (Jugador = 67, PH = 647.99)
# [OK] Resultados guardados en: C:\Users\Fabian\Desktop\big-data\Datasets\TP1\out_ph
